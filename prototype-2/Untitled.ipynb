# %%
from dummy import create_dummy_network, NetworkEnvironment
from Routing import MessageRoutingEnv, QLearningAgent
import matplotlib.pyplot as plt
import networkx as nx

def visualize_network(graph):
    # Separate nodes based on their type
    machines = [node for node, data in graph.nodes(data=True) if data['type'] == 'machine']
    switches = [node for node, data in graph.nodes(data=True) if data['type'] == 'switch']
    routers = [node for node, data in graph.nodes(data=True) if data['type'] == 'router']
    servers = [node for node, data in graph.nodes(data=True) if data['type'] == 'server']
    
    plt.figure(figsize=(18,15))

    # Draw the network graph using matplotlib with different colors for each type
    pos = nx.spring_layout(graph)  # You can choose different layout algorithms
    nx.draw_networkx_nodes(graph, pos, nodelist=machines, node_color='lightblue', label='Machines')
    nx.draw_networkx_nodes(graph, pos, nodelist=switches, node_color='green', label='Switches')
    nx.draw_networkx_nodes(graph, pos, nodelist=routers, node_color='orange', label='Routers')
    nx.draw_networkx_nodes(graph, pos, nodelist=servers, node_color='yellow', label='Servers')
    nx.draw_networkx_edges(graph, pos)
    nx.draw_networkx_labels(graph, pos)

    # Display the legend
    plt.legend()

    # Display the graph
    plt.show()

# %%
import pickle
import pandas as pd

num_machines_per_switch = 5
num_switches = 15
num_routers = 7
num_servers = 1

# Create the dummy network
dummy_network = create_dummy_network(num_machines_per_switch, num_switches, num_routers, num_servers)
visualize_network(dummy_network)

# Get the total number of nodes in the network
num_nodes = len(dummy_network.nodes)

# Create the environment using the total number of nodes
env = NetworkEnvironment(num_nodes)

# Create the Q-learning agent
agent = QLearningAgent(env.num_nodes)

episode_rewards = []


for episode in range(1000):
    state, target_node = env.reset()
    total_reward = 0

    while True:
        action = agent.select_action(state)
        next_state, reward = env.step(action)
        agent.update_q_table(state, action, reward, next_state)
        state = next_state
        total_reward += reward

        if state == target_node:
            break

    print(f"Episode: {episode}, Total Reward: {total_reward}")
    # Store the total reward for the episode
    episode_rewards.append(total_reward)

q_table_df = pd.DataFrame(agent.q_table, columns=[f"Node_{i}" for i in range(agent.num_actions)])

# Save the Q-table as a CSV file
q_table_df.to_csv('q_table2.csv', index=False)


        
    

#if __name__ == "__main__":
    #main()
# Out:
# Episode: 0, Total Reward: 1
# Episode: 1, Total Reward: 1
# Episode: 2, Total Reward: 1
# Episode: 3, Total Reward: 1
# Episode: 4, Total Reward: 1
# Episode: 5, Total Reward: 1
# Episode: 6, Total Reward: 1
# Episode: 7, Total Reward: 1
# Episode: 8, Total Reward: 1
# Episode: 9, Total Reward: 1
# Episode: 10, Total Reward: 1
# Episode: 11, Total Reward: 1
# Episode: 12, Total Reward: 1
# Episode: 13, Total Reward: 1
# Episode: 14, Total Reward: 1
# Episode: 15, Total Reward: 1
# Episode: 16, Total Reward: 1
# Episode: 17, Total Reward: 1
# Episode: 18, Total Reward: 1
# Episode: 19, Total Reward: 1
# Episode: 20, Total Reward: 1
# Episode: 21, Total Reward: 1
# Episode: 22, Total Reward: 1
# Episode: 23, Total Reward: 1
# Episode: 24, Total Reward: 1
# Episode: 25, Total Reward: 1
# Episode: 26, Total Reward: 1
# Episode: 27, Total Reward: 1
# Episode: 28, Total Reward: 1
# Episode: 29, Total Reward: 1
# Episode: 30, Total Reward: 1
# Episode: 31, Total Reward: 1
# ...

# %%
start_node = 6  # Specify the start node
end_node = 26  
shortest_path = nx.shortest_path(dummy_network, start_node, end_node)
print("Optimal Path:", shortest_path)
# Out:
# Optimal Path: [6, 83, 26]

# %%
num_nodes = len(dummy_network.nodes)

# Create the environment using the total number of nodes
env = NetworkEnvironment(num_nodes)

    # Load the Q-table from the saved file
q_table = pd.read_csv("q_table.csv")

    # Create the Q-learning agent with the loaded Q-table
agent = QLearningAgent(env.num_nodes)
agent.q_table = q_table.values  # Set the Q-table values

    # Testing
start_node = 1  # Specify the start node
end_node = 99  # Specify the end node
total_rewards = []

for episode in range(1):
    state = env.reset(start_node)
    target_node = env.set_target(end_node)
    total_reward = 0

    while True:
        action = agent.select_action(state)
        next_state, reward, done, _ = env.step(action)
        state = next_state
        total_reward += reward

        if done:
            break

    total_rewards.append(total_reward)
    print(f"Testing Episode: {episode}, Total Reward: {total_reward}")

average_reward = sum(total_rewards) / num_episodes
print(f"Average Testing Reward: {average_reward}")

# Find the best path after testing
best_path = env.episode_paths[np.argmax(agent.q_table[state, :])]
print("Best Path:", best_path)

# Visualize the network with the best path highlighted
visualize_network(dummy_network, best_path)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [42], in <cell line: 18>()
#      16 total_rewards = []
#      18 for episode in range(1):
# ---> 19     state = env.reset(start_node)
#      20     target_node = env.set_target(end_node)
#      21     total_reward = 0
#
# TypeError: reset() takes 1 positional argument but 2 were given

# %%
start_node = 1  # Specify the start node
end_node = 69  
shortest_path = nx.shortest_path(dummy_network, start_node, end_node)
print("Optimal Path:", shortest_path)
# Out:
# Optimal Path: [1, 251, 262, 269, 264, 252, 69]

# %% [markdown]
# def train_agent(env, agent, num_episodes=1000):
#     for episode in range(num_episodes):
#         state, target_node = env.reset()
#         total_reward = 0
#
#         while True:
#             action = agent.select_action(state)
#             next_state, reward, done, _ = env.step(action)
#             agent.update_q_table(state, action, reward, next_state)
#             state = next_state
#             total_reward += reward
#
#             if done:
#                 break
#
#         print(f"Training Episode: {episode}, Total Reward: {total_reward}")

# %% [markdown]
# def test_agent(env, agent, start_node, end_node, num_episodes=1):
#     total_rewards = []
#
#     for episode in range(num_episodes):
#         state = env.set_state(start_node)
#         target_node = env.set_target(end_node)
#         total_reward = 0
#
#         while True:
#             action = agent.select_action(state)
#             next_state, reward, done, _ = env.step(action)
#             state = next_state
#             total_reward += reward
#
#             if done:
#                 break
#
#         total_rewards.append(total_reward)
#         print(f"Testing Episode: {episode}, Total Reward: {total_reward}")
#
#     average_reward = sum(total_rewards) / num_episodes
#     print(f"Average Testing Reward: {average_reward}")
#
#     # Find the best path after testing
#     best_path = env.episode_paths[np.argmax(agent.q_table[state, :])]
#     print("Best Path:", best_path)
#
#     # Visualize the network with the best path highlighted
#     visualize_network(env.graph, best_path)

# %% [markdown]
# def main():
#     num_machines_per_switch = 9
#     num_switches = 26
#     num_routers = 8
#     num_servers = 1
#
#     dummy_network = create_dummy_network(num_machines_per_switch, num_switches, num_routers, num_servers)
#     visualize_network(dummy_network)
#     num_nodes = len(dummy_network.nodes)
#
#     # Create the environment using the dummy network
#     env = NetworkEnvironment(num_nodes)
#
#     # Create the Q-learning agent
#     agent = QLearningAgent(env.num_nodes)
#
#     for episode in range(1000):
#         state, target_node = env.reset()
#         total_reward = 0
#
#         while True:
#             action = agent.select_action(state)
#             next_state, reward = env.step(action)
#             agent.update_q_table(state, action, reward, next_state)
#             state = next_state
#             total_reward += reward
#
#             if state == target_node:
#                 break
#
#         print(f"Episode: {episode}, Total Reward: {total_reward}")
#
#     best_path = env.episode_paths[np.argmax(agent.q_table[state, :])]
#     print("Best Path:", best_path)
#
#     # Visualize the network with the best path highlighted
#     visualize_network(dummy_network, best_path)
#
# if __name__ == "__main__":
#     main()
